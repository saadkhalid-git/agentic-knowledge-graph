# %% [markdown]
# # Final Demonstration: Multi-Source Knowledge Graph Query System
#
# ## System Overview
#
# This notebook demonstrates a complete solution for querying across structured CSV data and unstructured text reviews using an ADK-enhanced knowledge graph.
#
# **Key Features:**
# - Unified knowledge graph combining CSV and markdown data
# - Natural language query interface
# - Full traceability for all answers
# - Multi-hop relationship traversal

# %%
# Setup and imports
import os
import sys
import json
from datetime import datetime

# Add parent directory to path
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath('./'))))

# Import our query engine
from src.query_engine import KnowledgeGraphQueryEngine, QueryResult

# %% [markdown]
# ## Step 1: Verify Graph is Built
#
# First, ensure the knowledge graph has been constructed from our data sources.

# %%
from src.neo4j_for_adk import graphdb

# Check graph statistics
stats_query = """
MATCH (n)
WITH labels(n)[0] as label, count(*) as count
RETURN label, count
ORDER BY count DESC
LIMIT 10
"""

result = graphdb.send_query(stats_query)
if result['status'] == 'success':
    print("📊 Knowledge Graph Statistics:")
    print("="*40)
    total = 0
    for item in result['query_result']:
        label = item.get('label', 'Unknown')
        count = item.get('count', 0)
        print(f"{label:20} {count:8} nodes")
        total += count
    print("="*40)
    print(f"{'Total':20} {total:8} nodes")
else:
    print("❌ Could not connect to graph database")
# Out:
# 📊 Knowledge Graph Statistics:
# ========================================
# Part                       88 nodes
# Assembly                   64 nodes
# Feature                    47 nodes
# Issue                      34 nodes
# Supplier                   20 nodes
# User                       18 nodes
# Product                    12 nodes
# Rating                     12 nodes
# ========================================
# Total                     295 nodes

# %% [markdown]
# ## Step 2: Initialize Query Engine

# %%
# Create query engine with LLM support
engine = KnowledgeGraphQueryEngine(use_llm=True)

# %% [markdown]
# ## Example Question 1: Product Catalog
#
# **Question:** "What products are available in the catalog?"
#
# **Capability Demonstrated:** Simple entity listing from structured CSV data

# %%
# Question 1
question1 = "What products are available in the catalog?"
print(f"🔍 Question: {question1}\n")

# Get answer
result1 = engine.answer_question(question1)

# Display answer
print("📝 Answer:")
print("="*60)
print(result1.answer)
print("="*60)

# Show traceability
print(f"\n🔗 Traceability:")
print(f"   Confidence: {result1.confidence:.1%}")
print(f"   Evidence items: {len(result1.evidence)}")

# Show the Cypher query used
print(f"\n💻 Cypher Query Used:")
print("```cypher")
print(result1.query_used)
print("```")
# Out:
# 🔍 Question: What products are available in the catalog?
#
# 📝 Answer:
# ============================================================
# The catalog contains 12 products:
# 1. Gothenburg Table ($$489)
# 2. Helsingborg Dresser ($$212)
# 3. Jönköping Coffee Table ($$212)
# 4. Linköping Bed ($$790)
# 5. Malmo Desk ($None)
# 6. Malmö Desk ($$289)
# 7. Norrköping Nightstand ($$135)
# 8. Orebro Lamp ($None)
# 9. Stockholm Chair ($$246)
# 10. Uppsala Sofa ($$1289)
# 11. Västerås Bookshelf ($$222)
# 12. Örebro Lamp ($$111)
# ============================================================
#
# 🔗 Traceability:
#    Confidence: 90.0%
#    Evidence items: 12
#
# 💻 Cypher Query Used:
# ```cypher
#
#                 MATCH (p:Product)
#                 RETURN p.product_id as id, p.product_name as name,
#                        p.price as price, p.description as description
#                 ORDER BY p.product_name
#
# ```

# %% [markdown]
# ### Evidence for Question 1

# %%
# Show sample evidence
if result1.evidence:
    print("📋 Sample Evidence (first 3 items):")
    for i, item in enumerate(result1.evidence[:3], 1):
        print(f"\n{i}. Product: {item.get('name', 'N/A')}")
        print(f"   ID: {item.get('id', 'N/A')}")
        print(f"   Price: ${item.get('price', 'N/A')}")
        print(f"   Description: {item.get('description', 'N/A')[:100]}...")
# Out:
# 📋 Sample Evidence (first 3 items):
#
# 1. Product: Gothenburg Table
#    ID: P-1001
#    Price: $$489
#    Description: Modern design that brings people together...
#
# 2. Product: Helsingborg Dresser
#    ID: P-1007
#    Price: $$212
#    Description: Spacious drawers with smooth-gliding mechanism...
#
# 3. Product: Jönköping Coffee Table
#    ID: P-1008
#    Price: $$212
#    Description: Centerpiece for your living room with hidden storage...

# %% [markdown]
# ## Example Question 2: Customer Reviews
#
# **Question:** "What are customers saying about the Malmo Desk?"
#
# **Capability Demonstrated:** Text extraction and analysis from unstructured markdown reviews

# %%
# Question 2
question2 = "What are customers saying about the Malmo Desk?"
print(f"🔍 Question: {question2}\n")

# Get answer
result2 = engine.answer_question(question2)

# Display answer
print("📝 Answer:")
print("="*60)
print(result2.answer)
print("="*60)

# Show traceability
print(f"\n🔗 Traceability:")
print(f"   Confidence: {result2.confidence:.1%}")
print(f"   Evidence items: {len(result2.evidence)}")
print(f"   Source: Extracted from markdown reviews")

# Show the Cypher query used
print(f"\n💻 Cypher Query Used:")
print("```cypher")
print(result2.query_used)
print("```")
# Out:
# 🔍 Question: What are customers saying about the Malmo Desk?
#
# 📝 Answer:
# ============================================================
# Customer feedback for Malmo Desk:
# • 7 customer reviews found
# • Ratings: 5, 4, 3, 2
# • Issues reported: edges of the desk are a bit sharp, desk wobbles slightly when typing, finish has inconsistencies and scratches out of the box, assembly was more complicated than advertised
# • Features praised: clean lines fit perfectly with Scandinavian-inspired living room, The dresser provides good storage., cable management system is effective, perfect surface area for dual monitor setup, drawer slides are smooth
# ============================================================
#
# 🔗 Traceability:
#    Confidence: 90.0%
#    Evidence items: 1
#    Source: Extracted from markdown reviews
#
# 💻 Cypher Query Used:
# ```cypher
#
#                 MATCH (p:Product)
#                 WHERE toLower(p.product_name) CONTAINS toLower($product_name)
#                 OPTIONAL MATCH (p)-[:REVIEWED_BY]->(u:User)
#                 OPTIONAL MATCH (p)-[:HAS_RATING]->(r:Rating)
#                 OPTIONAL MATCH (p)-[:HAS_ISSUE]->(i:Issue)
#                 OPTIONAL MATCH (p)-[:INCLUDES_FEATURE]->(f:Feature)
#                 RETURN p.product_name as product,
#                        collect(DISTINCT u.id) as reviewers,
#                        collect(DISTINCT r.value) as ratings,
#                        collect(DISTINCT i.description) as issues,
#                        collect(DISTINCT f.description) as features
#
# ```

# %% [markdown]
# ## Example Question 3: Multi-Hop Query
#
# **Question:** "Which suppliers provide parts for the Stockholm Chair, and what are their contact details?"
#
# **Capability Demonstrated:** Complex multi-hop relationship traversal across multiple CSV sources
#
# Query path: Product → Assembly → Part → Supplier

# %%
# Question 3
question3 = "Find products that have customer reviews mentioning both quality issues AND positive features, then show which suppliers provide parts for those products?"
print(f"🔍 Question: {question3}\n")

# Get answer
result3 = engine.answer_question(question3)

# Display answer
print("📝 Answer:")
print("="*60)
print(result3.answer)
print("="*60)

# Show traceability
print(f"\n🔗 Traceability:")
print(f"   Confidence: {result3.confidence:.1%}")
print(f"   Evidence items: {len(result3.evidence)}")
print(f"   Query hops: Product → Assembly → Part → Supplier")

# Show the Cypher query used
print(f"\n💻 Cypher Query Used:")
print("```cypher")
if result3.query_used:
    # Format for readability
    formatted_query = result3.query_used.replace('MATCH', '\nMATCH').replace('RETURN', '\nRETURN')
    print(formatted_query)
print("```")
# Out:
# 🔍 Question: Find products that have customer reviews mentioning both quality issues AND positive features, then show which suppliers provide parts for those products?
#
# 📝 Answer:
# ============================================================
# No customer reviews found for Norrköping Nightstand in the system.
# ============================================================
#
# 🔗 Traceability:
#    Confidence: 90.0%
#    Evidence items: 1
#    Query hops: Product → Assembly → Part → Supplier
#
# 💻 Cypher Query Used:
# ```cypher
#
#
# MATCH (p:Product)
#                 WHERE toLower(p.product_name) CONTAINS toLower($product_name)
#                 OPTIONAL
# MATCH (p)-[:REVIEWED_BY]->(u:User)
#                 OPTIONAL
# MATCH (p)-[:HAS_RATING]->(r:Rating)
#                 OPTIONAL
# MATCH (p)-[:HAS_ISSUE]->(i:Issue)
#                 OPTIONAL
# MATCH (p)-[:INCLUDES_FEATURE]->(f:Feature)
#
# RETURN p.product_name as product,
#                        collect(DISTINCT u.id) as reviewers,
#                        collect(DISTINCT r.value) as ratings,
#                        collect(DISTINCT i.description) as issues,
#                        collect(DISTINCT f.description) as features
#
# ```

# %% [markdown]
# ## Additional Demonstrations
#
# ### Demonstrating Graph Connectivity

# %%
# Additional question to show graph connectivity
bonus_question = "How many suppliers are in the system?"

bonus_query = "MATCH (s:Supplier) RETURN count(s) as supplier_count"
result = graphdb.send_query(bonus_query)

if result['status'] == 'success':
    count = result['query_result'][0]['supplier_count']
    print(f"🔍 Question: {bonus_question}")
    print(f"📝 Answer: There are {count} suppliers in the system.")
    print(f"\n💻 Query: {bonus_query}")
# Out:
# 🔍 Question: How many suppliers are in the system?
# 📝 Answer: There are 20 suppliers in the system.
#
# 💻 Query: MATCH (s:Supplier) RETURN count(s) as supplier_count

# %%
# Show relationship statistics
rel_query = """
MATCH ()-[r]->()
RETURN type(r) as relationship_type, count(r) as count
ORDER BY count DESC
"""

result = graphdb.send_query(rel_query)
if result['status'] == 'success':
    print("📊 Relationship Statistics:")
    print("="*40)
    for item in result['query_result']:
        rel_type = item.get('relationship_type', 'Unknown')
        count = item.get('count', 0)
        print(f"{rel_type:20} {count:8} relationships")
# Out:
# 📊 Relationship Statistics:
# ========================================
# SUPPLIES                  176 relationships
# REVIEWED_BY                40 relationships
# INCLUDES_FEATURE           38 relationships
# HAS_RATING                 35 relationships
# HAS_ISSUE                  24 relationships

# %% [markdown]
# ## System Capabilities Summary
#
# This demonstration showcases the following capabilities:
#
# 1. **Structured Data Queries** ✅
#    - Direct entity listing from CSV sources
#    - Maintains referential integrity
#
# 2. **Unstructured Text Analysis** ✅
#    - Extracts entities from markdown reviews
#    - Identifies ratings, issues, and features
#
# 3. **Multi-Hop Traversal** ✅
#    - Navigates complex relationships
#    - Connects products → assemblies → parts → suppliers
#
# 4. **Full Traceability** ✅
#    - Shows Cypher queries used
#    - Provides confidence scores
#    - Returns evidence with source attribution
#
# 5. **Natural Language Interface** ✅
#    - Converts questions to graph queries
#    - No need to know Cypher syntax

# %% [markdown]
# ## Performance Metrics

# %%
# Measure query performance
import time

test_questions = [
    "What products are available?",
    "What are customers saying about the Uppsala Sofa?",
    "Which suppliers provide parts for the Gothenburg Table?"
]

print("⏱️ Query Performance Test:")
print("="*50)

for q in test_questions:
    start = time.time()
    result = engine.answer_question(q)
    elapsed = time.time() - start
    
    print(f"Question: {q[:40]}...")
    print(f"  Time: {elapsed:.2f}s")
    print(f"  Success: {'✅' if result.confidence > 0 else '❌'}")
    print(f"  result: { result}")
    print()
# Out:
# ⏱️ Query Performance Test:
# ==================================================
# Question: What products are available?...
#   Time: 0.04s
#   Success: ✅
#   result: QueryResult(question='What products are available?', answer='The catalog contains 12 products:\n1. Gothenburg Table ($$489)\n2. Helsingborg Dresser ($$212)\n3. Jönköping Coffee Table ($$212)\n4. Linköping Bed ($$790)\n5. Malmo Desk ($None)\n6. Malmö Desk ($$289)\n7. Norrköping Nightstand ($$135)\n8. Orebro Lamp ($None)\n9. Stockholm Chair ($$246)\n10. Uppsala Sofa ($$1289)\n11. Västerås Bookshelf ($$222)\n12. Örebro Lamp ($$111)', evidence=[{'id': 'P-1001', 'name': 'Gothenburg Table', 'price': '$489', 'description': 'Modern design that brings people together'}, {'id': 'P-1007', 'name': 'Helsingborg Dresser', 'price': '$212', 'description': 'Spacious drawers with smooth-gliding mechanism'}, {'id': 'P-1008', 'name': 'Jönköping Coffee Table', 'price': '$212', 'description': 'Centerpiece for your living room with hidden storage'}, {'id': 'P-1006', 'name': 'Linköping Bed', 'price': '$790', 'description': 'Comfortable platform with hidden storage options'}, {'id': None, 'name': 'Malmo Desk', 'price': None, 'description': None}, {'id': 'P-1002', 'name': 'Malmö Desk', 'price': '$289', 'description': 'Functional design with ample storage solutions'}, {'id': 'P-1009', 'name': 'Norrköping Nightstand', 'price': '$135', 'description': 'Compact bedside solution with convenient drawer'}, {'id': None, 'name': 'Orebro Lamp', 'price': None, 'description': None}, {'id': 'P-1000', 'name': 'Stockholm Chair', 'price': '$246', 'description': 'Ergonomic design with minimalist Scandinavian style'}, {'id': 'P-1003', 'name': 'Uppsala Sofa', 'price': '$1289', 'description': 'Plush comfort with clean lines and removable covers'}, {'id': 'P-1004', 'name': 'Västerås Bookshelf', 'price': '$222', 'description': 'Simple yet elegant display for your favorite items'}, {'id': 'P-1005', 'name': 'Örebro Lamp', 'price': '$111', 'description': 'Stylish accent piece that brightens any room'}], query_used='\n                MATCH (p:Product)\n                RETURN p.product_id as id, p.product_name as name,\n                       p.price as price, p.description as description\n                ORDER BY p.product_name\n            ', confidence=0.9, timestamp='2025-11-14T12:58:40.525586')
#
# Question: What are customers saying about the Upps...
#   Time: 0.01s
#   Success: ✅
#   result: QueryResult(question='What are customers saying about the Uppsala Sofa?', answer='Customer feedback for Uppsala Sofa:\n• 7 customer reviews found\n• Ratings: 5, 4, 3, 2\n• Issues reported: assembly was more complicated than advertised, cushions are already losing their shape, frame creaks whenever someone sits down, one of the legs arrived with a small chip\n• Features praised: clean lines fit perfectly with Scandinavian-inspired living room, removable covers are easy to wash, fabric is durable and has held up well, cushions are on the firmer side for proper back support, frame feels incredibly solid - no squeaking or wobbling', evidence=[{'product': 'Uppsala Sofa', 'reviewers': ['@scandi_lover', '@designer_dave', '@interior_whiz', '@entertainer_emma', '@familyfirst', '@petite_patty', '@furniture_lover92'], 'ratings': [5, 4, 3, 2], 'issues': ['assembly was more complicated than advertised', 'cushions are already losing their shape', 'frame creaks whenever someone sits down', 'one of the legs arrived with a small chip'], 'features': ['clean lines fit perfectly with Scandinavian-inspired living room', 'removable covers are easy to wash', 'fabric is durable and has held up well', 'cushions are on the firmer side for proper back support', 'frame feels incredibly solid - no squeaking or wobbling']}], query_used='\n                MATCH (p:Product)\n                WHERE toLower(p.product_name) CONTAINS toLower($product_name)\n                OPTIONAL MATCH (p)-[:REVIEWED_BY]->(u:User)\n                OPTIONAL MATCH (p)-[:HAS_RATING]->(r:Rating)\n                OPTIONAL MATCH (p)-[:HAS_ISSUE]->(i:Issue)\n                OPTIONAL MATCH (p)-[:INCLUDES_FEATURE]->(f:Feature)\n                RETURN p.product_name as product,\n                       collect(DISTINCT u.id) as reviewers,\n                       collect(DISTINCT r.value) as ratings,\n                       collect(DISTINCT i.description) as issues,\n                       collect(DISTINCT f.description) as features\n            ', confidence=0.9, timestamp='2025-11-14T12:58:40.533646')
#
# Question: Which suppliers provide parts for the Go...
#   Time: 0.01s
#   Success: ✅
#   result: QueryResult(question='Which suppliers provide parts for the Gothenburg Table?', answer='No results found for this query.', evidence=[], query_used='\n                MATCH (p:Product)\n                WHERE toLower(p.product_name) CONTAINS toLower($product_name)\n                MATCH (p)<-[:CONTAINS]-(a:Assembly)<-[:IS_PART_OF]-(part:Part)\n                MATCH (part)<-[:SUPPLIES]-(s:Supplier)\n                RETURN p.product_name as product,\n                       collect(DISTINCT {\n                           supplier: s.name,\n                           specialty: s.specialty,\n                           city: s.city,\n                           country: s.country,\n                           email: s.contact_email,\n                           website: s.website,\n                           parts: part.part_name\n                       }) as suppliers\n            ', confidence=0.5, timestamp='2025-11-14T12:58:40.540271')

# %% [markdown]
# ## Conclusion
#
# This system successfully demonstrates:
#
# - **Integration** of structured CSV and unstructured markdown data
# - **Intelligent querying** using natural language
# - **Complex traversals** across multiple data relationships
# - **Full traceability** for audit and verification
#
# The knowledge graph approach provides a flexible, scalable solution for answering complex business questions across heterogeneous data sources.
